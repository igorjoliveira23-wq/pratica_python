# %%
# 1) Durante as aulas de programação no BIA/UFG, o professor desafia os alunos a criar um
# contador simples. Escreva um programa que utilize o laço while para exibir na tela todos os
# números inteiros de 1 até N, onde N é fornecido pelo usuário. O programa deve também calcular e
# exibir a soma de todos os números do intervalo.
# Entrada: um número inteiro positivo N.
# Saída: números de 1 a N (um por linha) e a soma total.
p = 0
soma = 0
n = int(input("digite um número qualquer: "))
while p < n:
  p += 1
  soma += p
  print(p)
print(f"A soma dos termos é: {soma}")
# Out:
# digite um número qualquer: 0
# A soma dos termos é: 0

# %%
# 2) Um aluno do BIA precisa calcular a média de notas de uma turma sem saber de antemão
# quantas notas serão inseridas. Desenvolva um programa que leia notas repetidamente utilizando o
# laço while, encerrando a entrada quando o usuário digitar -1 (sentinela). Ao final, o programa deve
# exibir a média das notas inseridas, a maior e a menor nota da turma.
# Desafio extra: exibir também quantas notas ficaram acima da média.
# Entrada: notas reais digitadas uma a uma; -1 para encerrar.
# Saída: quantidade de notas, média, maior nota e menor nota.

notas  = []
notas_boas =[]
nota = float(input("Digite a nota do aluno(digite -1 para SAIR): "))
while nota != -1:
 notas.append(nota)
 nota = float(input("Digite a nota do aluno(digite -1 para SAIR): "))
 media = sum(notas)/len(notas)#soma das notas/quantidade de notas

notas_boas =[]
for nota in notas:
 if nota > media:
  notas_boas.append(nota)

print(f"{len(notas)} notas foram inseridas no sistemas ")
print(f"A média geral da turma é de {media:.2f} pontos")
print(f"A maior nota da turma é de {max(notas)} pontos e a menor nota é de {min(notas)} pontos")
print(f"O total de {len(notas_boas)} notas acima da média, sendo elas: {notas_boas}")
# Out:
# Digite a nota do aluno(digite -1 para SAIR): 10
# Digite a nota do aluno(digite -1 para SAIR): 5
# Digite a nota do aluno(digite -1 para SAIR): 8
# Digite a nota do aluno(digite -1 para SAIR): 10
# Digite a nota do aluno(digite -1 para SAIR): 8
# Digite a nota do aluno(digite -1 para SAIR): 8
# Digite a nota do aluno(digite -1 para SAIR): 8
# Digite a nota do aluno(digite -1 para SAIR): -1
# 7 notas foram inseridas no sistemas
# A média geral da turma é de 8.14 pontos
# A maior nota da turma é de 10.0 pontos e a menor nota é de 5.0 pontos
# O total de 2 notas acima da média, sendo elas: [10.0, 10.0]

# %%
# 3) O sistema de autenticação de um laboratório do CEIA/UFG deve solicitar uma senha ao usuário.
# Utilizando o laço while, crie um programa que permita ao usuário tentar digitar a senha correta até
# 3 vezes. A senha correta é bia2025. O programa deve exibir:
# • "Acesso liberado!" se a senha estiver correta;
# • "Senha incorreta. Tentativa X de 3." a cada erro;
# • "Acesso bloqueado. Entre em contato com o suporte." após 3 erros.
# Entrada: senha digitada pelo usuário (até 3 tentativas).
# Saída: mensagem de acesso liberado ou bloqueado após esgotar tentativas.

senha = input("Digite sua senha: ")
contador = 1
while senha != "bia2025":
  if contador <= 3:
    print (f"Senha incorreta. Tentativa {contador} de 3")
    senha = input("digite  sua senha: ")
    contador +=1
  else:
    print("ACESSO BLOQUEADO. Entre em contato com o suporte.")
    break
if senha == "bia2025":
  print("Acesso liberado! Seja bem vindo!")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_5707/4118094412.py in <cell line: 0>()
#       8 # Saída: mensagem de acesso liberado ou bloqueado após esgotar tentativas.
#       9
# ---> 10 senha = input("Digite sua senha: ")
#      11 contador = 1
#      12 while senha != "bia2025":
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
# ...

# %%
# 4) Durante uma aula de matemática computacional no BIA/UFG, o professor solicita um programa
# para exibir a tabuada. Utilize o laço for para criar um programa que leia um número inteiro N e
# exiba a tabuada completa desse número, de 1 a 10, formatada de forma clara.
# Desafio extra: permitir que o usuário escolha o intervalo da tabuada (ex.: de 1 a 20).
# Entrada: um número inteiro N.
# Saída: tabuada de N, de N×1 até N×10.
number = int(input("Digite um número qualquer "))
intervalo = int(input("Escolha um intervalo da tabuada entre 1 e 20. Digite-o: "))
for n in range(intervalo+1):
  print(f"{number} X {n} = {n*number}")
# Out:
# Digite um número qualquer 7
# Escolha um intervalo da tabuada entre 1 e 20. Digite-o: 10
# 7 X 0 = 0
# 7 X 1 = 7
# 7 X 2 = 14
# 7 X 3 = 21
# 7 X 4 = 28
# 7 X 5 = 35
# 7 X 6 = 42
# 7 X 7 = 49
# 7 X 8 = 56
# 7 X 9 = 63
# 7 X 10 = 70

# %%
# 5) Um pesquisador do CEIA/UFG coletou dados de temperatura (em °C) ao longo de 7 dias
# consecutivos em um experimento de IoT com sensores ESP32. Utilizando o laço for, crie um
# programa que leia as 7 temperaturas e calcule e exiba:
# • a média das temperaturas;
# • o dia (1 a 7) em que ocorreu a maior temperatura;
# • o dia (1 a 7) em que ocorreu a menor temperatura.
# Entrada: sete valores reais de temperatura.
# Saída: temperatura média, maior e menor temperatura registrada nos 7 dias.
temperaturas = []
for T in range(7):
  T = (int(input("Digite a temperatura: ")))
  temperaturas.append(T)
media = sum(temperaturas)/7
maior_t = max(temperaturas)
Dia_maior_t = temperaturas.index(maior_t)
menor_t = min(temperaturas)
Dia_menor_t = temperaturas.index(menor_t)
#saídas
print(f"A média das temperaturas é igual a {media:.2f}ºC")
print(f"Com base nos registros de temperaturas dos últimos 7 dias, a maior temperatura foi de {maior_t}ºC registrada no {Dia_maior_t}º dia e a menor temperatura foi de {menor_t}ºC registrada no {Dia_menor_t}º dia.")
# Out:
# Digite a temperatura: 23
# Digite a temperatura: 30
# Digite a temperatura: 34
# Digite a temperatura: 21
# Digite a temperatura: 18
# Digite a temperatura: 17
# Digite a temperatura: 21
# A média das temperaturas é igual a 23.43ºC
# Com base nos registros de temperaturas dos últimos 7 dias, a maior temperatura foi de 34ºC registrada no 2º dia e a menor temperatura foi de 17ºC registrada no 5º dia.

# %%
# 6) Em uma atividade de análise de dados no laboratório do BIA, os alunos precisam verificar quais
# números de uma sequência são primos. Utilizando o laço for, escreva um programa que leia um
# número inteiro N e liste todos os números primos de 2 até N.
# Dica: um número é primo se for divisível apenas por 1 e por ele mesmo. Utilize um laço for
# interno para verificar os divisores.
# Entrada: um número inteiro positivo N.
# Saída: lista de todos os números primos entre 2 e N e a quantidade total encontrada.

n = int(input("digite um número inteiro: "))
numero = n
primos = []
for c in range (2, n+1):
  if numero % c == 0: #se resto da divisão dos números entre 2 e o antecessor pelo numero digitado for igual a zero, o número não é primo.
    break
  else:
    primos.append(numero)


print(f"Existem {len(primos)} números primos de 2 até {numero}. Sendo eles: {primos}")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_5707/3465655386.py in <cell line: 0>()
#       7 # Saída: lista de todos os números primos entre 2 e N e a quantidade total encontrada.
#       8
# ----> 9 n = int(input("digite um número inteiro: "))
#      10 numero = n
#      11 primos = []
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
# ...
